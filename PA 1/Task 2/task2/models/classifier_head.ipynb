# %% [markdown]
# # Classifier head
# Written only; no cells executed. See task2/README.md for execution order.

# %%
from torch import nn

def make_classifier_head(input_dim=512, classes=7):
    return nn.Linear(input_dim, classes)
