# %% [markdown]
# # Source-only objective
# Written only; no cells executed. See task2/README.md for execution order.

# %%
def source_only_objective(model, x, y, target_x, discriminator, cfg, progress, rng_state):
    logits = model(x)
    classification = nn.functional.cross_entropy(logits, y)
    return logits, classification, classification, classification.new_zeros(()), 0, 0, 0.0, rng_state
