# %% [markdown]
# # Reuse Task 2 backbone and BatchNorm policy
# Written only; no cells executed during creation. See README.md for run order.

# %%
load_notebook(TASK2 / 'task2/models/backbone.ipynb')
